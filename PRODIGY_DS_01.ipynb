# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("/Users/adityakumar/Downloads/API_SP.POP.TOTL_DS2_en_excel_v2_84058-2.xls")

# %%
df['Column5'] = pd.to_numeric(df['Column5'], errors='coerce')
df['Column6'] = pd.to_numeric(df['Column6'], errors='coerce')
df['Column7'] = pd.to_numeric(df['Column7'], errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Column5'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ...

# %%
df.shape
# Out:
# (269, 68)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 68 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Data Source                   268 non-null    object
#  1   World Development Indicators  268 non-null    object
#  2   Unnamed: 2                    267 non-null    object
#  3   Unnamed: 3                    267 non-null    object
#  4   Unnamed: 4                    265 non-null    float64
#  5   Unnamed: 5                    265 non-null    float64
#  6   Unnamed: 6                    265 non-null    float64
#  7   Unnamed: 7                    265 non-null    float64
#  8   Unnamed: 8                    265 non-null    float64
#  9   Unnamed: 9                    265 non-null    float64
#  10  Unnamed: 10                   265 non-null    float64
#  11  Unnamed: 11                   265 non-null    float64
# ...

# %%
df = pd.read_excel("/Users/adityakumar/Downloads/API_SP.POP.TOTL_DS2_en_excel_v2_84058-2.xls")
print(df.columns)
# Out:
# Index(['Data Source', 'World Development Indicators', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
#        'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40',
#        'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44',
#        'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48',
#        'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52',
#        'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56',
# ...

# %%
print(df['Column5'].unique())
print(df['Column6'].unique())
print(df['Column7'].unique())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Column5'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ...

# %%
print(df[df.columns[0]].unique())
# Out:
# ['Last Updated Date' nan 'Country Name' 'Aruba'
#  'Africa Eastern and Southern' 'Afghanistan' 'Africa Western and Central'
#  'Angola' 'Albania' 'Andorra' 'Arab World' 'United Arab Emirates'
#  'Argentina' 'Armenia' 'American Samoa' 'Antigua and Barbuda' 'Australia'
#  'Austria' 'Azerbaijan' 'Burundi' 'Belgium' 'Benin' 'Burkina Faso'
#  'Bangladesh' 'Bulgaria' 'Bahrain' 'Bahamas, The' 'Bosnia and Herzegovina'
#  'Belarus' 'Belize' 'Bermuda' 'Bolivia' 'Brazil' 'Barbados'
#  'Brunei Darussalam' 'Bhutan' 'Botswana' 'Central African Republic'
#  'Canada' 'Central Europe and the Baltics' 'Switzerland' 'Channel Islands'
#  'Chile' 'China' "Cote d'Ivoire" 'Cameroon' 'Congo, Dem. Rep.'
#  'Congo, Rep.' 'Colombia' 'Comoros' 'Cabo Verde' 'Costa Rica'
#  'Caribbean small states' 'Cuba' 'Curacao' 'Cayman Islands' 'Cyprus'
#  'Czechia' 'Germany' 'Djibouti' 'Dominica' 'Denmark' 'Dominican Republic'
#  'Algeria' 'East Asia & Pacific (excluding high income)'
# ...

# %%
df.columns = df.iloc[0]

# %%
df = df.drop(0)

# %%
df = df.reset_index(drop=True)

# %%
print(df['Country'].unique())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:191, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:234, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File index.pyx:242, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File index.pyx:134, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'Country'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ...

# %%
df.columns = df.iloc[0]
df = df.drop(0)
df = df.reset_index(drop=True)
print(df['CountryName'].unique())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:191, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:234, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File index.pyx:242, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File index.pyx:134, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'CountryName'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 4
# ...

# %%
df.columns = df.iloc[0]
df = df.drop(0)
df = df.reset_index(drop=True)
print(df['Country Name'].unique())
# Out:
# ['Aruba' 'Africa Eastern and Southern' 'Afghanistan'
#  'Africa Western and Central' 'Angola' 'Albania' 'Andorra' 'Arab World'
#  'United Arab Emirates' 'Argentina' 'Armenia' 'American Samoa'
#  'Antigua and Barbuda' 'Australia' 'Austria' 'Azerbaijan' 'Burundi'
#  'Belgium' 'Benin' 'Burkina Faso' 'Bangladesh' 'Bulgaria' 'Bahrain'
#  'Bahamas, The' 'Bosnia and Herzegovina' 'Belarus' 'Belize' 'Bermuda'
#  'Bolivia' 'Brazil' 'Barbados' 'Brunei Darussalam' 'Bhutan' 'Botswana'
#  'Central African Republic' 'Canada' 'Central Europe and the Baltics'
#  'Switzerland' 'Channel Islands' 'Chile' 'China' "Cote d'Ivoire"
#  'Cameroon' 'Congo, Dem. Rep.' 'Congo, Rep.' 'Colombia' 'Comoros'
#  'Cabo Verde' 'Costa Rica' 'Caribbean small states' 'Cuba' 'Curacao'
#  'Cayman Islands' 'Cyprus' 'Czechia' 'Germany' 'Djibouti' 'Dominica'
#  'Denmark' 'Dominican Republic' 'Algeria'
#  'East Asia & Pacific (excluding high income)'
#  'Early-demographic dividend' 'East Asia & Pacific'
# ...

# %%
df = pd.read_excel("/Users/adityakumar/Downloads/API_SP.POP.TOTL_DS2_en_excel_v2_84058-2.xls")
df
# Out:
#                      Data Source World Development Indicators  \
# 0              Last Updated Date          2024-03-28 00:00:00
# 1                            NaN                          NaN
# 2                   Country Name                 Country Code
# 3                          Aruba                          ABW
# 4    Africa Eastern and Southern                          AFE
# ..                           ...                          ...
# 264                       Kosovo                          XKX
# 265                  Yemen, Rep.                          YEM
# 266                 South Africa                          ZAF
# 267                       Zambia                          ZMB
# 268                     Zimbabwe                          ZWE
#
#             Unnamed: 2      Unnamed: 3   Unnamed: 4   Unnamed: 5   Unnamed: 6  \
# 0                  NaN             NaN          NaN          NaN          NaN
# ...

# %%
year_column = '2024'

# %%
population_data = df[2024].dropna()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2024
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ...

# %%
population_data = df['2024'].dropna()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2024'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ...

# %%
print(df.columns)
# Out:
# Index(['Data Source', 'World Development Indicators', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
#        'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40',
#        'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44',
#        'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48',
#        'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52',
#        'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56',
# ...

# %%
print(df.head())
# Out:
#                    Data Source World Development Indicators  \
# 0            Last Updated Date          2024-03-28 00:00:00
# 1                          NaN                          NaN
# 2                 Country Name                 Country Code
# 3                        Aruba                          ABW
# 4  Africa Eastern and Southern                          AFE
#
#           Unnamed: 2      Unnamed: 3   Unnamed: 4   Unnamed: 5   Unnamed: 6  \
# 0                NaN             NaN          NaN          NaN          NaN
# 1                NaN             NaN          NaN          NaN          NaN
# 2     Indicator Name  Indicator Code       1960.0       1961.0       1962.0
# 3  Population, total     SP.POP.TOTL      54608.0      55811.0      56682.0
# 4  Population, total     SP.POP.TOTL  130692579.0  134169237.0  137835590.0
#
#     Unnamed: 7   Unnamed: 8   Unnamed: 9  ...  Unnamed: 58  Unnamed: 59  \
# ...

# %%
column_2024_index = df.columns.get_loc(2024)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2024
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ...

# %%
population_data_2023 = df['Unnamed: 67'].dropna().astype(float)

# %%
plt.figure(figsize=(10, 6))

# %%
plt.hist(population_data_2023, bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Population')
plt.ylabel('Frequency')
plt.title('Population Distribution in 2023')
plt.grid(True)
plt.show()

# %%
df_final = df.drop(['Country Code',	'Indicator Name',	'Indicator Code'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df_final = df.drop(['Country Code',	'Indicator Name',	'Indicator Code'], axis=1)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
# ...

# %%
df = pd.read_excel("/Users/adityakumar/Downloads/API_SP.POP.TOTL_DS2_en_excel_v2_84058-2.xls")
df.head()
# Out:
#                    Data Source World Development Indicators  \
# 0            Last Updated Date          2024-03-28 00:00:00
# 1                          NaN                          NaN
# 2                 Country Name                 Country Code
# 3                        Aruba                          ABW
# 4  Africa Eastern and Southern                          AFE
#
#           Unnamed: 2      Unnamed: 3   Unnamed: 4   Unnamed: 5   Unnamed: 6  \
# 0                NaN             NaN          NaN          NaN          NaN
# 1                NaN             NaN          NaN          NaN          NaN
# 2     Indicator Name  Indicator Code       1960.0       1961.0       1962.0
# 3  Population, total     SP.POP.TOTL      54608.0      55811.0      56682.0
# 4  Population, total     SP.POP.TOTL  130692579.0  134169237.0  137835590.0
#
#     Unnamed: 7   Unnamed: 8   Unnamed: 9  ...  Unnamed: 58  Unnamed: 59  \
# ...

# %%
df_final = df.drop(['Country Code',	'Indicator Name',	'Indicator Code'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df_final = df.drop(['Country Code',	'Indicator Name',	'Indicator Code'], axis=1)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
# ...

# %%
df = pd.read_csv('/Users/adityakumar/Downloads/API_SP/API_SP.POP.TOTL_DS2_en_csv_v2_84031.csv',  encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df = pd.read_csv('/Users/adityakumar/Downloads/API_SP/API_SP.POP.TOTL_DS2_en_csv_v2_84031.csv',  encoding='utf-8')
#
# ...

# %%
df = pd.read_excel("/Users/adityakumar/Downloads/API_SP.POP.TOTL_DS2_en_excel_v2_84058-2.xls")

# %%
df
# Out:
#                      Data Source World Development Indicators  \
# 0              Last Updated Date          2024-03-28 00:00:00
# 1                            NaN                          NaN
# 2                   Country Name                 Country Code
# 3                          Aruba                          ABW
# 4    Africa Eastern and Southern                          AFE
# ..                           ...                          ...
# 264                       Kosovo                          XKX
# 265                  Yemen, Rep.                          YEM
# 266                 South Africa                          ZAF
# 267                       Zambia                          ZMB
# 268                     Zimbabwe                          ZWE
#
#             Unnamed: 2      Unnamed: 3   Unnamed: 4   Unnamed: 5   Unnamed: 6  \
# 0                  NaN             NaN          NaN          NaN          NaN
# ...

# %%
# Drop the specified columns from the DataFrame
df_final = df.drop(['Country Code', 'Indicator Name', 'Indicator Code'], axis=1)

# Check the resulting DataFrame
print(df_final)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 2
#       1 # Drop the specified columns from the DataFrame
# ----> 2 df_final = df.drop(['Country Code', 'Indicator Name', 'Indicator Code'], axis=1)
#       4 # Check the resulting DataFrame
#       5 print(df_final)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
# ...

# %%
# Check the column names in the DataFrame
print(df.columns)
# Out:
# Index(['Data Source', 'World Development Indicators', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
#        'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40',
#        'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44',
#        'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48',
#        'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52',
#        'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56',
# ...

# %%
column_names = ['Data Source', 'World Development Indicators', 'Country Name', 'Country Code', 
                'Indicator Name', 'Indicator Code'] + [f'Year {i}' for i in range(1960, 2024)]

df.columns = column_names
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 4
#       1 column_names = ['Data Source', 'World Development Indicators', 'Country Name', 'Country Code',
#       2                 'Indicator Name', 'Indicator Code'] + [f'Year {i}' for i in range(1960, 2024)]
# ----> 4 df.columns = column_names
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py:6310, in NDFrame.__setattr__(self, name, value)
#    6308 try:
#    6309     object.__getattribute__(self, name)
# -> 6310     return object.__setattr__(self, name, value)
#    6311 except AttributeError:
#    6312     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py:813, in NDFrame._set_axis(self, axis, labels)
# ...

# %%
# Define column names
column_names = ['Data Source', 'World Development Indicators', 'Country Name', 'Country Code', 
                'Indicator Name', 'Indicator Code'] + [f'Year {i}' for i in range(1960, 2024)]

# Check the number of columns in the DataFrame
print("Number of columns in the DataFrame:", len(df.columns))

# Check the number of elements in the column_names list
print("Number of elements in the column_names list:", len(column_names))
# Out:
# Number of columns in the DataFrame: 68
# Number of elements in the column_names list: 70

# %%
df.columns = column_names
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df.columns = column_names
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py:6310, in NDFrame.__setattr__(self, name, value)
#    6308 try:
#    6309     object.__getattribute__(self, name)
# -> 6310     return object.__setattr__(self, name, value)
#    6311 except AttributeError:
#    6312     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py:813, in NDFrame._set_axis(self, axis, labels)
#     808 """
#     809 This is called from the cython code when we set the `index` attribute
#     810 directly, e.g. `series.index = [1, 2, 3]`.
#     811 """
#     812 labels = ensure_index(labels)
# ...

# %%
# Remove the first two elements from column_names as they seem to be metadata
column_names = ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'] + [f'Year {i}' for i in range(1960, 2024)]

# Assign the adjusted column names to the DataFrame
df.columns = column_names

# %%
df_final = df.drop(['Country Code',	'Indicator Name',	'Indicator Code'], axis=1)

# %%
chosen_country = 'United States'


country_data = df_final[df_final['Country Name'] == chosen_country]


years = country_data.columns[2:].astype(int)
population = country_data.iloc[:, 2:].values.flatten()

plt.figure(figsize=(5, 3))
plt.bar(years, population, color='skyblue')
plt.xlabel('Year')
plt.ylabel('Population')
plt.title(f'Population of {chosen_country} Over the Years')


plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 7
#       1 chosen_country = 'United States'
#       4 country_data = df_final[df_final['Country Name'] == chosen_country]
# ----> 7 years = country_data.columns[2:].astype(int)
#       8 population = country_data.iloc[:, 2:].values.flatten()
#      10 plt.figure(figsize=(5, 3))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:1097, in Index.astype(self, dtype, copy)
#    1093     new_values = cls._from_sequence(self, dtype=dtype, copy=copy)
#    1095 else:
#    1096     # GH#13149 specifically use astype_array instead of astype
# -> 1097     new_values = astype_array(values, dtype=dtype, copy=copy)
#    1099 # pass copy=False because any copying will be done in the astype above
# ...

# %%
chosen_country = 'United States'

# %%
country_data = df_final[df_final['Country Name'] == chosen_country]

# %%
years = country_data.columns[2:].str.split().str[1].astype(int)
population = country_data.iloc[:, 2:].values.flatten()

# %%
plt.figure(figsize=(10, 6))
plt.bar(years, population, color='skyblue')
plt.xlabel('Year')
plt.ylabel('Population')
plt.title(f'Population of {chosen_country} Over the Years')
plt.show()

# %%
plt.hist(population, bins=20, color='skyblue', edgecolor='black')
plt.show()
